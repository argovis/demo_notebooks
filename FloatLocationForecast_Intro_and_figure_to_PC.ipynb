# %% [markdown]
# # Introduction to the Argone float location forecast API

# %% [markdown]
# Argovis provides an API that indexes and distributes Argo float location forecast data provided by [citation needed]. The schema for these data is similar, but not identical, to many of our other products; this notebook will highlight some of the details specific to this dataset.

# %% [markdown]
# ## Setup: Register an API key

# %% [markdown]
# In order to allocate Argovis's limited computing resources fairly, users are encouraged to register and request a free API key. This works like a password that identifies your requests to Argovis. To do so:
#
#  - Visit [https://argovis-keygen.colorado.edu/](https://argovis-keygen.colorado.edu/)
#  - Fill out the form under _New Account Registration_
#  - An API key will be emailed to you shortly.
#
# Treat this API key like a password - don't share it or leave it anywhere public. If you ever forget it or accidentally reveal it to a third party, see the same website above to change or deactivate your token.
#
# Put your API key in the quotes in the variable below before moving on:

# %%
API_ROOT='https://argovis-api.colorado.edu/'
API_KEY=''

from argovisHelpers import helpers as avh
import xarray, pandas

import matplotlib.pyplot as plt
import numpy as np
import cartopy.crs as ccrs

# %% [markdown]
# # Float location forecast data structure

# %% [markdown]
# Let's begin by looking at a float location forecast document. The `forecastOrigin` key will query the forecast for a float starting at the provided longitude, latitude string, in this case `x0,y0`

# %%
# Paul C.' paper
x0 = 22
y0 = -44
# x0 = -130 #22
# y0 = 32 #-44

flfSearch = {
    'forecastOrigin': str(x0) + ',' + str(y0),
    'data': 'all'
}

flf = avh.query('argone', options=flfSearch, apikey=API_KEY, apiroot=API_ROOT)
flf[1]
# Out:
# {'_id': '-130_32_-128.0_30.0',
#  'metadata': ['argone'],
#  'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#  'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 30]},
#  'data': [[0.01923076923076923],
#   [0.030083707815666574],
#   [0.03539530680820193],
#   [0.03763023582154097],
#   [0.03799816977066939],
#   [0.03726126889578032],
#   [0.035941296653470386],
#   [0.03430249930993108],
#   [0.032538804944536],
#   [0.03078296524600543],
#   [0.02907849680467692],
#   [0.02746582069418169],
#   [0.025957714653800208],
#   [0.0245595443487727],
#   [0.023282534922120374],
#   [0.022109719658308987],
#   [0.02103661902650058],
#   [0.020055761217675085],
#   [0.019149275475470098],
#   [0.018309019001893984]]}

# %% [markdown]
# We get an array of documents like the one illustrated above. These documents follow the conventions of Argovis' gridded documents, with the following modifications:
#
#  - `geolocation` specifies the location of the float at the beginning of the forecast. Valid locations are lattice points of a 2 degree square grid centered on 0,0.
#  - `geolocation_forecast` specifies the location of the float at the end of the forecast. These are populated over the same 2 degree grid as `geolocation`.
#  - No `timestamp` key is present: these forecasts do not take into account seasonal or long term variations, and so have no meaningful timestamp to associate with them.
#  - Data variables cover [90,1800] in steps of 90, and indicate number of days each forecast point covers. For example, if x0 = 22 and y0 = -44 were indicated in the previous code cell (as origin of interest), the above document indicates that a float initially at x0,y0 will have a 2.857% chance of being found in the 24,-42 grid cell after 90 days, or 0.066% after 1800 days.
#
# The array of documents `flf` found above contains a document for every possible destination endpoint, for all 20 timesteps. The `argone` endpoint supports the same `data` query string behavior as other Argovis API endpoints (as always, see [https://argovis-api.colorado.edu/docs/](https://argovis-api.colorado.edu/docs/) for always-up-to-date API documentation for all routes). For example, let's get only the 90 day forecast:

# %%
flfSearch90 = {
    'forecastOrigin': str(x0) + ',' + str(y0),
    'data': '90'
}

flf90 = avh.query('argone', options=flfSearch90, apikey=API_KEY, apiroot=API_ROOT)
flf90[1]
# Out:
# {'_id': '-130_32_-128.0_30.0',
#  'metadata': ['argone'],
#  'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#  'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 30]},
#  'data': [[0.01923076923076923]],
#  'data_info': [['90'], ['units'], [[None]]]}

# %% [markdown]
# We can also look backwards in time by querying all documents that have an endpoint of a given longitude, latitude with `forecastGeolocation`:

# %%
flfSearchReverse = {
    'forecastGeolocation':'24,-42',
    'data': 'all'
}

flfReverse = avh.query('argone', options=flfSearchReverse, apikey=API_KEY, apiroot=API_ROOT)
flfReverse[1]
# Out:
# {'_id': '-90_-56_24.0_-42.0',
#  'metadata': ['argone'],
#  'geolocation': {'type': 'Point', 'coordinates': [-90, -56]},
#  'geolocation_forecast': {'type': 'Point', 'coordinates': [24, -42]},
#  'data': [[None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [None],
#   [0.00010499539873719],
#   [0.00024041753171309148],
#   [0.0003787248381617915],
#   [0.0005055899832310555],
#   [0.000620739027433694]]}

# %% [markdown]
# Let's also have the metadata for these data documents on hand:

# %%
flfMeta = avh.query('argone/meta', options={'id':'argone'}, apikey=API_KEY, apiroot=API_ROOT)
flfMeta
# Out:
# [{'_id': 'argone',
#   'data_type': 'covariance',
#   'data_info': [['90',
#     '180',
#     '270',
#     '360',
#     '450',
#     '540',
#     '630',
#     '720',
#     '810',
#     '900',
#     '990',
#     '1080',
#     '1170',
#     '1260',
#     '1350',
#     '1440',
#     '1530',
#     '1620',
#     '1710',
#     '1800'],
#    ['units'],
#    [[None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None],
#     [None]]],
#   'date_updated_argovis': '2023-02-08T21:37:00.000Z',
#   'levels': [0],
#   'source': [{'source': ['tbd'], 'doi': 'tbd'}]}]

# %% [markdown]
# We can also fairly easily turn this information into an xarray data set, and plot it:

# %%
def flfgrid(originlist):
    # given a list of documents from the argovis float location forecast API for a single float origin,
    # return an xarray object representing this data:

    lon = []
    lat = []
    forecastDays = []
    prob = []
    for doc in originlist:
        for i,v in enumerate(doc['data']):
            lon.append(doc['geolocation_forecast']['coordinates'][0])
            lat.append(doc['geolocation_forecast']['coordinates'][1])
            forecastDays.append(int(flfMeta[0]['data_info'][0][i]))
            prob.append(v[0])
            
    df = pandas.DataFrame({"latitude": lat, 
                           "longitude": lon, 
                           "forecastDays": forecastDays, 
                           "probability": prob
                          }).set_index(["latitude","longitude","forecastDays"])
    return df.to_xarray()

# %%
ds = flfgrid(flf)

# %%
flf
# Out:
# [{'_id': '-130_32_-126.0_32.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-126, 32]},
#   'data': [[0.01923076923076923],
#    [0.05381376283075136],
#    [0.06516847758622568],
#    [0.0669194106943336],
#    [0.06430118687217783],
#    [0.059856462310717305],
#    [0.054936475279363746],
#    [0.050081340956258096],
#    [0.04555386274362443],
#    [0.04146578579436917],
#    [0.03779315212116263],
#    [0.034518024130614895],
#    [0.031599853639337296],
#    [0.029000443749557177],
#    [0.02669829895915271],
#    [0.024646691711648662],
#    [0.022818958883506386],
#    [0.0211884867469904],
#    [0.019721796981397595],
#    [0.018398582926705452]]},
#  {'_id': '-130_32_-128.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 30]},
#   'data': [[0.01923076923076923],
#    [0.030083707815666574],
#    [0.03539530680820193],
#    [0.03763023582154097],
#    [0.03799816977066939],
#    [0.03726126889578032],
#    [0.035941296653470386],
#    [0.03430249930993108],
#    [0.032538804944536],
#    [0.03078296524600543],
#    [0.02907849680467692],
#    [0.02746582069418169],
#    [0.025957714653800208],
#    [0.0245595443487727],
#    [0.023282534922120374],
#    [0.022109719658308987],
#    [0.02103661902650058],
#    [0.020055761217675085],
#    [0.019149275475470098],
#    [0.018309019001893984]]},
#  {'_id': '-130_32_-130.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 30]},
#   'data': [[0.01923076923076923],
#    [0.03803330689928628],
#    [0.04627912836074067],
#    [0.04835919959155667],
#    [0.04717488894668995],
#    [0.044516963282147784],
#    [0.04143389824070634],
#    [0.0383744774914488],
#    [0.03556045011807141],
#    [0.033075434121222026],
#    [0.030894828796668494],
#    [0.02899549804454044],
#    [0.027338060163753647],
#    [0.025885697513225323],
#    [0.024619332521908843],
#    [0.02349921409413955],
#    [0.022504663042181575],
#    [0.021617361881281234],
#    [0.02081110952234997],
#    [0.020071937798462777]]},
#  {'_id': '-130_32_-124.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-124, 30]},
#   'data': [[None],
#    [0.0017754868270332188],
#    [0.007309265354845436],
#    [0.012123537874037664],
#    [0.015347644028491956],
#    [0.01719171189106628],
#    [0.018054461353916865],
#    [0.01823937081311729],
#    [0.017984205578038055],
#    [0.017466405918103618],
#    [0.016785956148621176],
#    [0.016021578190631887],
#    [0.015221473461849683],
#    [0.014419470950648472],
#    [0.013644475227211744],
#    [0.01290264823896646],
#    [0.012203087975484226],
#    [0.011549308115346591],
#    [0.010936440666104719],
#    [0.010363613581001001]]},
#  {'_id': '-130_32_-130.0_38.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 38]},
#   'data': [[None],
#    [None],
#    [0.0006165206921623235],
#    [0.0011527425262408768],
#    [0.0015956280217992753],
#    [0.0019793587378550037],
#    [0.0023053719696896745],
#    [0.0025743466409069815],
#    [0.0027925673172282967],
#    [0.002965401988027764],
#    [0.0030959295849107625],
#    [0.003190954838447067],
#    [0.0032545607110492],
#    [0.0032912965079188016],
#    [0.00330727326451851],
#    [0.003305010320847722],
#    [0.0032883591586021815],
#    [0.0032602882987334846],
#    [0.003221796517846981],
#    [0.0031747425384007367]]},
#  {'_id': '-130_32_-120.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-120, 30]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [0.0008328570038377171],
#    [0.0018991585506674985],
#    [0.0029504870558317514],
#    [0.003846845514645864],
#    [0.004542180536697004],
#    [0.0050382612176529005],
#    [0.005365313823271628],
#    [0.005552189032358567],
#    [0.005627994510850209],
#    [0.0056196023992679135],
#    [0.005551394906448139],
#    [0.005439406999520004],
#    [0.0052988964616569306],
#    [0.005140512109484857],
#    [0.004969563223114223],
#    [0.004791799695234221]]},
#  {'_id': '-130_32_-134.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.0001343611309164447],
#    [0.00024600775220394677],
#    [0.0003535211443276893],
#    [0.00046212095086418085],
#    [0.0005810448127406347],
#    [0.0007013198048230671],
#    [0.0008203470880592845],
#    [0.0009369838445859083],
#    [0.0010519408786276293]]},
#  {'_id': '-130_32_-114.0_24.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-114, 24]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [7.953627902276001e-05]]},
#  {'_id': '-130_32_-140.0_16.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-140, 16]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [7.87035246319669e-05]]},
#  {'_id': '-130_32_-148.0_28.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-148, 28]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.167106251321331e-05]]},
#  {'_id': '-130_32_-130.0_46.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 46]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.489772465967101e-05]]},
#  {'_id': '-130_32_-148.0_24.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-148, 24]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.961362797493185e-05]]},
#  {'_id': '-130_32_-146.0_24.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-146, 24]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [7.911592402305407e-05]]},
#  {'_id': '-130_32_-114.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-114, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [7.775587716608165e-05]]},
#  {'_id': '-130_32_-138.0_16.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-138, 16]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.144604023881366e-05]]},
#  {'_id': '-130_32_-132.0_16.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-132, 16]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.953815485624501e-05]]},
#  {'_id': '-130_32_-150.0_34.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-150, 34]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.823536241124602e-05]]},
#  {'_id': '-130_32_-148.0_36.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-148, 36]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.068270164665878e-05],
#    [0.00013492617397897337]]},
#  {'_id': '-130_32_-126.0_16.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-126, 16]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.142691236284049e-05],
#    [0.000150541059846337]]},
#  {'_id': '-130_32_-120.0_16.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-120, 16]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.399683027073735e-05],
#    [0.0001865652017799607]]},
#  {'_id': '-130_32_-148.0_26.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-148, 26]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [7.649016928866217e-05],
#    [0.00013109332876184223]]},
#  {'_id': '-130_32_-146.0_22.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-146, 22]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.645689723639988e-05],
#    [0.0001443251500599934]]},
#  {'_id': '-130_32_-146.0_28.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-146, 28]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [7.588011727864137e-05],
#    [0.0001318866451520486]]},
#  {'_id': '-130_32_-116.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-116, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [7.918183978159317e-05],
#    [0.00014347760781983638]]},
#  {'_id': '-130_32_-134.0_16.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 16]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.183000699262095e-05],
#    [0.00014482867470430247]]},
#  {'_id': '-130_32_-142.0_22.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-142, 22]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.67017269775891e-05],
#    [0.00014148281812392216]]},
#  {'_id': '-130_32_-144.0_22.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-144, 22]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010229716178318505],
#    [0.00017251459613937058],
#    [0.00022906983969790717]]},
#  {'_id': '-130_32_-136.0_42.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-136, 42]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [7.954788272534009e-05],
#    [0.00012482125644437122],
#    [0.00015261275188618853]]},
#  {'_id': '-130_32_-132.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-132, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.073193521252839e-05],
#    [0.0001588939612121089],
#    [0.00021873817750441072]]},
#  {'_id': '-130_32_-126.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-126, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.234905833992616e-05],
#    [0.0001753628550556508],
#    [0.0002609573275567853],
#    [0.0003647964879406658]]},
#  {'_id': '-130_32_-116.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-116, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010089135075786962],
#    [0.00018841893021434716],
#    [0.0002681780413127312],
#    [0.0003593242061538026]]},
#  {'_id': '-130_32_-136.0_16.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-136, 16]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.779392092226872e-05],
#    [0.00015373555904510153],
#    [0.00021353565590202266],
#    [0.00027552059825878053]]},
#  {'_id': '-130_32_-128.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.647719835132766e-05],
#    [0.00017713126430748862],
#    [0.0002571510732489657],
#    [0.0003505909290352012]]},
#  {'_id': '-130_32_-134.0_44.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 44]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.379283629223407e-05],
#    [0.00015846164011835582],
#    [0.00022117800883811518],
#    [0.0002786258632524078]]},
#  {'_id': '-130_32_-122.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-122, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.311640790551741e-05],
#    [0.0001915363512333236],
#    [0.0003070521087364838],
#    [0.0004329866756200218],
#    [0.00056746718651678]]},
#  {'_id': '-130_32_-128.0_46.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 46]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.273553952289968e-05],
#    [0.00016240391083731023],
#    [0.0002202713806270655],
#    [0.000270461351033809],
#    [0.0003146505904333655]]},
#  {'_id': '-130_32_-120.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-120, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.896119302253497e-05],
#    [0.00017114923599329424],
#    [0.0002880089431920503],
#    [0.00042091745927512025],
#    [0.0005661698128436012]]},
#  {'_id': '-130_32_-148.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-148, 30]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.815090815274386e-05],
#    [0.00016533454293643122],
#    [0.00024123204843169705],
#    [0.0003170191857846537],
#    [0.00039511225360302647]]},
#  {'_id': '-130_32_-118.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-118, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [8.930232543950051e-05],
#    [0.0001673819012071713],
#    [0.00027124764809594357],
#    [0.0003854109760665268],
#    [0.0005058898851240005]]},
#  {'_id': '-130_32_-146.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-146, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.093562284513592e-05],
#    [0.00016957119740725271],
#    [0.00024133848924412512],
#    [0.0003136266946460218],
#    [0.00038779119242358267]]},
#  {'_id': '-130_32_-148.0_32.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-148, 32]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010378549187218722],
#    [0.0001875849205761951],
#    [0.00026779498337859765],
#    [0.0003491984834895986],
#    [0.00043340698563152627]]},
#  {'_id': '-130_32_-114.0_22.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-114, 22]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.86201379317281e-05],
#    [0.00019086481233148106],
#    [0.00028177523186185914],
#    [0.00038827591043679284],
#    [0.000500032864068624]]},
#  {'_id': '-130_32_-146.0_26.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-146, 26]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010666722059236478],
#    [0.0001940735242672786],
#    [0.00027303641750861166],
#    [0.00034446364426773946],
#    [0.00041185036043175807],
#    [0.0004900239130335273]]},
#  {'_id': '-130_32_-118.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-118, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010433729166911097],
#    [0.00019154994106448055],
#    [0.0003045639950267495],
#    [0.0004247536142937409],
#    [0.0005474297644723476],
#    [0.000670384852304562]]},
#  {'_id': '-130_32_-148.0_34.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-148, 34]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.920881069990531e-05],
#    [0.00018128645340516992],
#    [0.00025884743573312686],
#    [0.00033717559026508843],
#    [0.0004171062729926898],
#    [0.0004970071651967995]]},
#  {'_id': '-130_32_-144.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-144, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00012246878407101724],
#    [0.00021395241740669197],
#    [0.0002991644973648602],
#    [0.00038327220168150194],
#    [0.0004664771441898024],
#    [0.0005606414210971382]]},
#  {'_id': '-130_32_-134.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00011284278180078183],
#    [0.00019670299186245663],
#    [0.0002717736011089212],
#    [0.0003445317489764172],
#    [0.000414008252737928],
#    [0.0004928285824061902]]},
#  {'_id': '-130_32_-144.0_28.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-144, 28]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010400335828506732],
#    [0.00019495456622877267],
#    [0.0002766030949662479],
#    [0.00035092952105193986],
#    [0.0004322522819358592],
#    [0.0005107673504251251],
#    [0.0005846245893588569]]},
#  {'_id': '-130_32_-124.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-124, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00012675892413798324],
#    [0.0002452124949174187],
#    [0.0003725451162231324],
#    [0.0005289706382620182],
#    [0.0007080450239937022],
#    [0.0009048621062642761],
#    [0.001117936932642185]]},
#  {'_id': '-130_32_-134.0_42.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 42]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.652270969307924e-05],
#    [0.00015156783890858734],
#    [0.00018451226285088996],
#    [0.00022135901315296924],
#    [0.00026089069028197774],
#    [0.00029564374638181215],
#    [0.00032531617970714465]]},
#  {'_id': '-130_32_-130.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00013066321265704637],
#    [0.0002357630449739458],
#    [0.00033384295823931287],
#    [0.0004320378857553],
#    [0.0005456575032066678],
#    [0.0006642860334225867],
#    [0.0007862236535270248]]},
#  {'_id': '-130_32_-146.0_32.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-146, 32]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00013260350321404348],
#    [0.00023524446904847946],
#    [0.00032940887219454776],
#    [0.00042134110294569677],
#    [0.0005108046647792385],
#    [0.000610347814073033],
#    [0.000710393949338689]]},
#  {'_id': '-130_32_-116.0_24.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-116, 24]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00011146417805041659],
#    [0.00021438596605671579],
#    [0.0003134034571856485],
#    [0.0004265762101726966],
#    [0.0005435440105330547],
#    [0.0006613627590858793],
#    [0.0007806465516818877]]},
#  {'_id': '-130_32_-120.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-120, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010344353579207212],
#    [0.0001913267435601954],
#    [0.0003060787940789851],
#    [0.00042849223124128197],
#    [0.0005534221257409558],
#    [0.0006780342738759962],
#    [0.0008003351818294981]]},
#  {'_id': '-130_32_-144.0_26.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-144, 26]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [9.982935659860993e-05],
#    [0.00017291917254676423],
#    [0.00024973124431271285],
#    [0.00032005921596916614],
#    [0.00038367329108092055],
#    [0.00045450382872058796],
#    [0.0005259956263460341]]},
#  {'_id': '-130_32_-130.0_44.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 44]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010175558992213243],
#    [0.00017795981700839342],
#    [0.00024043713500504317],
#    [0.00029361665655696484],
#    [0.0003397190626127421],
#    [0.0003795439274043425],
#    [0.0004288324633737523]]},
#  {'_id': '-130_32_-146.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-146, 30]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00013493463630530472],
#    [0.0002467848287354828],
#    [0.00035541837773471995],
#    [0.000466579214191453],
#    [0.0005896156425172026],
#    [0.0007171773567749546],
#    [0.0008472043052918486]]},
#  {'_id': '-130_32_-134.0_22.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 22]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010375945316872545],
#    [0.00017328903634514123],
#    [0.0002287011637995537],
#    [0.00027338566820754324],
#    [0.00031201146154747613],
#    [0.000344121615722403],
#    [0.00038152594454084996],
#    [0.00041555994797697803]]},
#  {'_id': '-130_32_-144.0_24.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-144, 24]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00010302291089762137],
#    [0.00017503650212390219],
#    [0.0002474487757521091],
#    [0.00031159430377005403],
#    [0.0003696775310035653],
#    [0.00042361842866247917],
#    [0.0004866773947940089],
#    [0.000550774851400983]]},
#  {'_id': '-130_32_-122.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-122, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00015268411509718362],
#    [0.00032796472830547054],
#    [0.0005211215657134733],
#    [0.000729827458037378],
#    [0.0009525570109399495],
#    [0.0011908558072155448],
#    [0.0014386872675285628],
#    [0.0016907781855028325]]},
#  {'_id': '-130_32_-142.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-142, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.0001340200709935458],
#    [0.00024158982805681065],
#    [0.00034482614666175355],
#    [0.0004485549912336177],
#    [0.000556358471244302],
#    [0.0006796622370302068],
#    [0.0008078793143227546],
#    [0.0009382409799368875]]},
#  {'_id': '-130_32_-132.0_44.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-132, 44]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00011682119681436224],
#    [0.00019914609795644122],
#    [0.0002784945514273488],
#    [0.0003510095899222331],
#    [0.0004359780138028377],
#    [0.0005167059301785971],
#    [0.00059152080786622],
#    [0.0006599101809338278]]},
#  {'_id': '-130_32_-142.0_38.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-142, 38]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00011394008819695316],
#    [0.00020436165372320463],
#    [0.0002860347163042531],
#    [0.000361357954747811],
#    [0.0004308157445438369],
#    [0.0005041119786644274],
#    [0.0005722064364090294],
#    [0.000633641876855612]]},
#  {'_id': '-130_32_-146.0_34.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-146, 34]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.0001469226844667108],
#    [0.00026487732606971816],
#    [0.0003757205730062602],
#    [0.0004844897831482475],
#    [0.0005906312884150905],
#    [0.0007057551739366936],
#    [0.0008184227117645303],
#    [0.0009282794396810654]]},
#  {'_id': '-130_32_-136.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-136, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00011438839413355223],
#    [0.0002039122091520665],
#    [0.0002872052768653348],
#    [0.0003735173813585926],
#    [0.00046031668001209075],
#    [0.0005591806767164558],
#    [0.0006605308839350207],
#    [0.0007619841664814132]]},
#  {'_id': '-130_32_-132.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-132, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00013043063953196816],
#    [0.0002509751972540081],
#    [0.00037193419127625697],
#    [0.0004970380248909077],
#    [0.0006385963955629817],
#    [0.0007857376950341211],
#    [0.0009343690013981238],
#    [0.0010846408675555053]]},
#  {'_id': '-130_32_-138.0_40.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-138, 40]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00012245835841056388],
#    [0.0002144250836030139],
#    [0.00028377677703165307],
#    [0.00033770323352230573],
#    [0.0003800739392613251],
#    [0.0004234537089497251],
#    [0.0004613379518010314],
#    [0.0004962588360770205],
#    [0.0005269677260465718]]},
#  {'_id': '-130_32_-130.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00012321166805409883],
#    [0.00023629022304303999],
#    [0.0003482593115907826],
#    [0.0004594173870748052],
#    [0.0005874291620410084],
#    [0.0007200667962876733],
#    [0.0008538677670106873],
#    [0.0009872491527938903],
#    [0.0011208590504470327]]},
#  {'_id': '-130_32_-144.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-144, 30]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.0001209121152978373],
#    [0.00022466869020874343],
#    [0.0003245512411598185],
#    [0.0004220446465585309],
#    [0.0005199621880608975],
#    [0.0006298202824008483],
#    [0.0007402565409413805],
#    [0.0008485497192782908],
#    [0.0009549778060940674]]},
#  {'_id': '-130_32_-124.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-124, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00016902005868691736],
#    [0.0003547125091159942],
#    [0.0005895651445922273],
#    [0.0008683709170779548],
#    [0.0011917053845417397],
#    [0.0015553323869595948],
#    [0.0019529670573280229],
#    [0.0023769155497687772],
#    [0.0028195222293206654]]},
#  {'_id': '-130_32_-116.0_22.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-116, 22]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00014067603465955583],
#    [0.00030110023565705496],
#    [0.000486044795732659],
#    [0.0007197386877198984],
#    [0.00098403797248715],
#    [0.0012748907047045663],
#    [0.001585960112899028],
#    [0.0019146688209623385],
#    [0.002253300076800743]]},
#  {'_id': '-130_32_-140.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-140, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.000134293876146771],
#    [0.00022578949247630887],
#    [0.00030198705775423074],
#    [0.00037021620045013016],
#    [0.000435111301000912],
#    [0.0004960883227979029],
#    [0.0005667451976885868],
#    [0.0006361429422006514],
#    [0.0007024834293617886]]},
#  {'_id': '-130_32_-138.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-138, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00011795213956410529],
#    [0.00022614438566962065],
#    [0.0003285390202322169],
#    [0.0004338805132739611],
#    [0.0005434037710624475],
#    [0.000667763407252446],
#    [0.0007968423942005699],
#    [0.0009272940594819754],
#    [0.0010597190002667005]]},
#  {'_id': '-130_32_-144.0_34.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-144, 34]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00013199274293457908],
#    [0.0002417392173640947],
#    [0.0003429824595076904],
#    [0.0004409232542184943],
#    [0.0005342176666041918],
#    [0.0006346023385405235],
#    [0.0007305152013715493],
#    [0.0008200903919371957],
#    [0.0009044039274497096],
#    [0.0009850086378486284]]},
#  {'_id': '-130_32_-142.0_28.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-142, 28]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00013469918564690804],
#    [0.0002631042311603844],
#    [0.0003876181599817244],
#    [0.0005200716372469737],
#    [0.0006509040231215826],
#    [0.0007810361693543325],
#    [0.0009083233466704094],
#    [0.0010326669169714552],
#    [0.0011518170628924615],
#    [0.0012648414903131977]]},
#  {'_id': '-130_32_-140.0_18.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-140, 18]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.000141681106385837],
#    [0.00027780935894628514],
#    [0.00041683313418754814],
#    [0.0005600924368767804],
#    [0.0007065065141312725],
#    [0.0008719363819358801],
#    [0.0010436618014916272],
#    [0.00122031000949189],
#    [0.0013997098746848797],
#    [0.0015821213997478008]]},
#  {'_id': '-130_32_-146.0_36.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-146, 36]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00012509423976355422],
#    [0.00023902661909509196],
#    [0.0003522700139021717],
#    [0.0004689531212471914],
#    [0.0005865459033130958],
#    [0.0007165712438464032],
#    [0.0008463173332822709],
#    [0.0009727711107829714],
#    [0.001096037670880826],
#    [0.001217101491370493]]},
#  {'_id': '-130_32_-126.0_44.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-126, 44]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00014053143678497836],
#    [0.0002483833440304484],
#    [0.000338716706621797],
#    [0.0004158175210589191],
#    [0.00048138907855903843],
#    [0.0005510412741107381],
#    [0.0006111353974632294],
#    [0.0006674525482826086],
#    [0.000717387939254416],
#    [0.0007599094654300158]]},
#  {'_id': '-130_32_-128.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00012575531926688384],
#    [0.00024292517853505052],
#    [0.0003596652424058291],
#    [0.00047527302547859895],
#    [0.0006082573415845581],
#    [0.000746217912920927],
#    [0.0008853799500250643],
#    [0.0010245958365459587],
#    [0.0011640923585859312],
#    [0.0013023633810743504]]},
#  {'_id': '-130_32_-126.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-126, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00015054625494447066],
#    [0.0002911808327556366],
#    [0.0004342218697132551],
#    [0.0005994926732325009],
#    [0.0007786136063997255],
#    [0.0009681753412554909],
#    [0.0011663488365178448],
#    [0.0013736688564398656],
#    [0.0015866161572638544],
#    [0.0018034718575171223]]},
#  {'_id': '-130_32_-142.0_26.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-142, 26]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.0001441099909729545],
#    [0.0002630518914031514],
#    [0.00039467047796253637],
#    [0.0005209706298606103],
#    [0.0006573643703208771],
#    [0.0007945163921161014],
#    [0.0009313767912247256],
#    [0.0010651085834341531],
#    [0.0011939555606103004],
#    [0.0013168751911261307]]},
#  {'_id': '-130_32_-142.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-142, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00015363416049838453],
#    [0.0002631737601941685],
#    [0.00035733339642679264],
#    [0.0004429901907234288],
#    [0.0005252636543831641],
#    [0.0006159495923823912],
#    [0.0007053576080435539],
#    [0.0007916098316277486],
#    [0.0008757282893518953],
#    [0.0009579617537425954]]},
#  {'_id': '-130_32_-128.0_44.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 44]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00018727857725602825],
#    [0.0003509403967531512],
#    [0.0005032187206313738],
#    [0.0006452568007785321],
#    [0.0007941969575368774],
#    [0.0009406233151345273],
#    [0.0010783083462951395],
#    [0.0012046842849074144],
#    [0.0013184082425604072],
#    [0.0014182920971595],
#    [0.0015041981919399802]]},
#  {'_id': '-130_32_-118.0_22.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-118, 22]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00019724980763192706],
#    [0.00044922052675412373],
#    [0.0007822330780804696],
#    [0.0011877853198730716],
#    [0.0016575788844376128],
#    [0.002180438641401535],
#    [0.002746433125255728],
#    [0.003340695897420069],
#    [0.003950943364485085],
#    [0.004564190755595965],
#    [0.005170127133778345]]},
#  {'_id': '-130_32_-142.0_24.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-142, 24]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.0001640473563672333],
#    [0.00028666121930001045],
#    [0.00039611895472915336],
#    [0.0004973887487475363],
#    [0.0005934513459452737],
#    [0.0006969952635457539],
#    [0.0007996025655616823],
#    [0.0008990285763909679],
#    [0.0009944075404381904],
#    [0.0010856361189634709],
#    [0.001173228904768206]]},
#  {'_id': '-130_32_-136.0_22.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-136, 22]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00021642091158668693],
#    [0.00037808864570215066],
#    [0.0005187991876762464],
#    [0.0006437337974442767],
#    [0.0007674477946467208],
#    [0.0008791121354942117],
#    [0.0009773864474178487],
#    [0.001064448335449102],
#    [0.0011414227799258756],
#    [0.001210941104478919],
#    [0.0012739874669124246],
#    [0.0013307470103134937]]},
#  {'_id': '-130_32_-144.0_36.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-144, 36]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.00018198535436528577],
#    [0.00036715074817213694],
#    [0.0005679192110354466],
#    [0.0007793825655362077],
#    [0.0010126501855183647],
#    [0.0012492128640193012],
#    [0.0014848194812034168],
#    [0.0017167835056869914],
#    [0.0019408566540462886],
#    [0.002156392308877949],
#    [0.002361054505251861],
#    [0.002554467734009068]]},
#  {'_id': '-130_32_-136.0_20.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-136, 20]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.0001394092855551155],
#    [0.0002972341775106994],
#    [0.0004669966722089949],
#    [0.0006505096195099595],
#    [0.000843977134634893],
#    [0.00105961240789161],
#    [0.001280512440447485],
#    [0.0015022215517457695],
#    [0.00172173699199835],
#    [0.0019392439597261432],
#    [0.0021535007694108346],
#    [0.0023632784859821494]]},
#  {'_id': '-130_32_-120.0_22.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-120, 22]},
#   'data': [[None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [None],
#    [0.0001457830242274931],
#    [0.00034614944186028954],
#    [0.0006654269744876211],
#    [0.0010838761843557736],
# ...
#    [0.00590755053025075],
#    [0.005576160239416686],
#    [0.005259692563719086],
#    [0.004960061444575084]]},
#  {'_id': '-130_32_-126.0_28.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-126, 28]},
#   'data': [[None],
#    [None],
#    [0.0025996495313586887],
#    [0.006534349934057555],
#    [0.010906111140633824],
#    [0.015163630925330376],
#    [0.019005962242166656],
#    [0.022276552172336463],
#    [0.02494449348006928],
#    [0.027056198351472084],
#    [0.028651989712799364],
#    [0.02980367931721782],
#    [0.030574647596192453],
#    [0.03103132406853662],
#    [0.031249298555988826],
#    [0.03126428868343321],
#    [0.031124042968445696],
#    [0.030866125906830216],
#    [0.030504538612375787],
#    [0.03006197568384907]]},
#  {'_id': '-130_32_-130.0_26.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 26]},
#   'data': [[None],
#    [None],
#    [0.0007435402292275243],
#    [0.0027603793273864472],
#    [0.005573221750071976],
#    [0.008607491569495793],
#    [0.011445885509628927],
#    [0.013881074957780579],
#    [0.015863935678334638],
#    [0.017421379863545753],
#    [0.018594751987323827],
#    [0.019448015892670208],
#    [0.020038459572507328],
#    [0.020419393626149102],
#    [0.020647073540549014],
#    [0.020748517801462304],
#    [0.020755604821656455],
#    [0.02069309270683272],
#    [0.020568853523851356],
#    [0.02039548196132361]]},
#  {'_id': '-130_32_-124.0_32.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-124, 32]},
#   'data': [[None],
#    [0.0026918671248568156],
#    [0.008544781823983391],
#    [0.01240041695246335],
#    [0.014560849621482928],
#    [0.015543844354254335],
#    [0.015784346756741903],
#    [0.015544436628183615],
#    [0.015016380833060762],
#    [0.01433525842501986],
#    [0.01357167812399451],
#    [0.012780729232070576],
#    [0.011994311130673238],
#    [0.011233771823612603],
#    [0.010517271194279077],
#    [0.009845958493681228],
#    [0.009223785922123523],
#    [0.008650811342041008],
#    [0.008121270215777066],
#    [0.0076327263570232]]},
#  {'_id': '-130_32_-134.0_34.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 34]},
#   'data': [[None],
#    [0.010930185926555902],
#    [0.01950989924768572],
#    [0.02478254344529167],
#    [0.02719154376665758],
#    [0.02782469883818889],
#    [0.027510551556535697],
#    [0.026697070932749412],
#    [0.025662515539037516],
#    [0.024565490144513258],
#    [0.023463958853727224],
#    [0.022398663926714784],
#    [0.021385768964327926],
#    [0.02042949881223208],
#    [0.01954157021423954],
#    [0.01871194343672442],
#    [0.0179397255806845],
#    [0.017221877885821083],
#    [0.0165474462305795],
#    [0.015912107178123153]]},
#  {'_id': '-130_32_-132.0_36.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-132, 36]},
#   'data': [[None],
#    [0.007589177677750351],
#    [0.01124982832607991],
#    [0.012649615293627473],
#    [0.012942480505983801],
#    [0.012687910381375424],
#    [0.012202455572614472],
#    [0.011623320922252076],
#    [0.011026791430230477],
#    [0.010452226176350728],
#    [0.009906076383379798],
#    [0.009399892029872235],
#    [0.008931309071519459],
#    [0.008496237132010635],
#    [0.008096470418082468],
#    [0.007726281517954822],
#    [0.007383768079179322],
#    [0.00706640631460291],
#    [0.0067687274446686695],
#    [0.006488499142194773]]},
#  {'_id': '-130_32_-132.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-132, 30]},
#   'data': [[None],
#    [0.01793814432989691],
#    [0.022353187860173505],
#    [0.021851708018886504],
#    [0.019957608921549738],
#    [0.0178820750100691],
#    [0.01602910699128249],
#    [0.014469194996295698],
#    [0.013194290657256474],
#    [0.012166838671694763],
#    [0.011331170799470979],
#    [0.010647607702381736],
#    [0.010081798635871653],
#    [0.009606836398289232],
#    [0.009207406309577868],
#    [0.008863781759724097],
#    [0.00856513514973089],
#    [0.00830301607403951],
#    [0.008066750422032662],
#    [0.007850576230746274]]},
#  {'_id': '-130_32_-132.0_28.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-132, 28]},
#   'data': [[None],
#    [0.0028865979381443303],
#    [0.009268766274220446],
#    [0.013417198158666975],
#    [0.01569260088674106],
#    [0.01679462425123272],
#    [0.017254676736771037],
#    [0.01735982726147377],
#    [0.017285508990685216],
#    [0.017130769390495803],
#    [0.016931943091160775],
#    [0.016715223278638575],
#    [0.016491052101597622],
#    [0.01626479309759083],
#    [0.01604793411664967],
#    [0.015834296627651127],
#    [0.01562610245642414],
#    [0.015424699397641363],
#    [0.015222721336997775],
#    [0.015018920319328116]]},
#  {'_id': '-130_32_-130.0_36.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 36]},
#   'data': [[None],
#    [0.002290028832790558],
#    [0.005586524382301271],
#    [0.007892550088608275],
#    [0.009081726159491784],
#    [0.009531928085185453],
#    [0.009574776370520338],
#    [0.00939923636688627],
#    [0.009115936255730645],
#    [0.008787769204544485],
#    [0.008438785636475326],
#    [0.008086228307410384],
#    [0.007740128084906568],
#    [0.007407286235777697],
#    [0.007092416926595271],
#    [0.006793103603912985],
#    [0.0065103556794307805],
#    [0.006243946139587765],
#    [0.0059904954287901165],
#    [0.005749070675772956]]},
#  {'_id': '-130_32_-126.0_34.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-126, 34]},
#   'data': [[None],
#    [0.003665521191294387],
#    [0.010624357450040247],
#    [0.015300672425814664],
#    [0.01771520373069213],
#    [0.018614077625903714],
#    [0.018620005701711326],
#    [0.018100608535456673],
#    [0.01729494669740088],
#    [0.016357225993444774],
#    [0.015361255001302976],
#    [0.014362147559853702],
#    [0.013389798489530215],
#    [0.012463075910629992],
#    [0.011598636362799914],
#    [0.010795343397793939],
#    [0.010055608693945726],
#    [0.009377953083626068],
#    [0.008755075729735986],
#    [0.008183487376219354]]},
#  {'_id': '-130_32_-130.0_28.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 28]},
#   'data': [[None],
#    [0.005693012600229096],
#    [0.01868040836021897],
#    [0.029679234644869993],
#    [0.036985717523466244],
#    [0.04127389180109901],
#    [0.04353072639761325],
#    [0.044454260517555806],
#    [0.044562643765825506],
#    [0.04420341362836427],
#    [0.043551512016583555],
#    [0.04273946550706137],
#    [0.041840327264312575],
#    [0.04090177035646335],
#    [0.03997526732642384],
#    [0.03905977312394097],
#    [0.038170452547446915],
#    [0.03731561935341857],
#    [0.03648015800589749],
#    [0.035663087340741965]]},
#  {'_id': '-130_32_-134.0_36.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 36]},
#   'data': [[None],
#    [0.003468232072849468],
#    [0.007197347390621316],
#    [0.010337944342729657],
#    [0.012542279284750678],
#    [0.013899742556434447],
#    [0.014636899224554552],
#    [0.014936449480018299],
#    [0.014946407560249167],
#    [0.014779086631816983],
#    [0.0144936531008273],
#    [0.014136503582043797],
#    [0.013737759081940179],
#    [0.013316995491202428],
#    [0.012895091093604774],
#    [0.012475637799351501],
#    [0.012065876023473972],
#    [0.011669822255201707],
#    [0.011284932724898796],
#    [0.010911894246422806]]},
#  {'_id': '-130_32_-134.0_32.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 32]},
#   'data': [[None],
#    [0.033473141253016384],
#    [0.040870879340776385],
#    [0.0394351983425048],
#    [0.03587044307864655],
#    [0.032301442477828776],
#    [0.029307027409198206],
#    [0.026882074810483405],
#    [0.02493180764418695],
#    [0.023352697335638002],
#    [0.022034382681673393],
#    [0.020911682417318594],
#    [0.019936099654545156],
#    [0.01907190292918718],
#    [0.018305340736865967],
#    [0.017611963761878173],
#    [0.016981457417219042],
#    [0.016405485530699617],
#    [0.01587010426910873],
#    [0.015368713255510022]]},
#  {'_id': '-130_32_-134.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-134, 30]},
#   'data': [[None],
#    [0.010263459335624284],
#    [0.01629473504617944],
#    [0.019713753449583232],
#    [0.02143261592604939],
#    [0.022103589072027734],
#    [0.022205604456042735],
#    [0.022004953092443196],
#    [0.021678918941425308],
#    [0.021326166503024515],
#    [0.020976854269903446],
#    [0.020651410733747093],
#    [0.02035401681422694],
#    [0.02008149820155619],
#    [0.019840465823267227],
#    [0.01961786182199654],
#    [0.019411446574233614],
#    [0.019219322389529576],
#    [0.019030096689420014],
#    [0.01883986858646739]]},
#  {'_id': '-130_32_-128.0_36.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 36]},
#   'data': [[None],
#    [0.005691883258312763],
#    [0.0079139895264226],
#    [0.008692258721915131],
#    [0.008939775022601256],
#    [0.00893441997491545],
#    [0.008794853179810939],
#    [0.008560506880647436],
#    [0.008263671469248474],
#    [0.007932687267036623],
#    [0.007580882644225641],
#    [0.007222075294680824],
#    [0.006863468598433545],
#    [0.006513878487439765],
#    [0.006180503530940791],
#    [0.00586244197552146],
#    [0.005561625772690178],
#    [0.00527868616126997],
#    [0.005011522459209516],
#    [0.004760032413390664]]},
#  {'_id': '-130_32_-128.0_34.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 34]},
#   'data': [[None],
#    [0.02178661891163706],
#    [0.02830996371633164],
#    [0.029049763937256452],
#    [0.02783023111105674],
#    [0.02599178584832802],
#    [0.02406121336380281],
#    [0.022191863635930304],
#    [0.0204496571647358],
#    [0.0188672416519458],
#    [0.017427415319179296],
#    [0.01612274171191024],
#    [0.014939687589079013],
#    [0.013866759594672914],
#    [0.01290082739079462],
#    [0.012025920432160839],
#    [0.011234630845307228],
#    [0.010518724914608446],
#    [0.009865753541961902],
#    [0.009268930578973579]]},
#  {'_id': '-130_32_-128.0_28.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 28]},
#   'data': [[None],
#    [0.0038487972508591066],
#    [0.009574829491909779],
#    [0.01683281547714237],
#    [0.023619574296587283],
#    [0.02894878937114817],
#    [0.03275513603854266],
#    [0.0352502312066397],
#    [0.036749607265038946],
#    [0.03754482705729396],
#    [0.03782317713059226],
#    [0.03774560497122778],
#    [0.037418605095283115],
#    [0.036922123232080585],
#    [0.03633266195590359],
#    [0.03567292151095551],
#    [0.03497586538173905],
#    [0.034263641270445365],
#    [0.03353356801686344],
#    [0.0327938699700321]]},
#  {'_id': '-130_32_-126.0_30.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-126, 30]},
#   'data': [[None],
#    [0.010824742268041237],
#    [0.01735305085033979],
#    [0.02089226215824553],
#    [0.022666543498455913],
#    [0.023319117734232526],
#    [0.02329378013206301],
#    [0.02283939996884045],
#    [0.022137403246782546],
#    [0.021314858036870048],
#    [0.020428423722464437],
#    [0.019526998800595163],
#    [0.018635938735533902],
#    [0.017772776903083768],
#    [0.016956786659782966],
#    [0.016184674276378805],
#    [0.015460603436952533],
#    [0.014784896914274303],
#    [0.014148958145264037],
#    [0.013550463877405109]]},
#  {'_id': '-130_32_-130.0_32.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 32]},
#   'data': [[0.5192307692307692],
#    [0.3321474995004834],
#    [0.23136032767315234],
#    [0.17027359092259456],
#    [0.1301811640100429],
#    [0.10242098703160853],
#    [0.08260940096054888],
#    [0.06804214808582594],
#    [0.057114972631890346],
#    [0.0487905029611965],
#    [0.04230962666630278],
#    [0.03718412870073797],
#    [0.033062697692665864],
#    [0.0296963611373372],
#    [0.026921567536544032],
#    [0.0245949989166785],
#    [0.02262351643004248],
#    [0.020935460562522577],
#    [0.01946700196488009],
#    [0.018176589529807403]]},
#  {'_id': '-130_32_-132.0_34.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-132, 34]},
#   'data': [[0.01923076923076923],
#    [0.025695914849392414],
#    [0.029193984702820867],
#    [0.029811607636009377],
#    [0.028859655185413977],
#    [0.027188466332421897],
#    [0.02532349024664698],
#    [0.023483665200665905],
#    [0.021780964720771463],
#    [0.020257382218315675],
#    [0.018896937730203466],
#    [0.017688903845673058],
#    [0.016613504190986877],
#    [0.015650744540256667],
#    [0.014792388676446496],
#    [0.014017952155903526],
#    [0.013317399432519278],
#    [0.012681364321070733],
#    [0.012096467376693594],
#    [0.011555718413337305]]},
#  {'_id': '-130_32_-128.0_32.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-128, 32]},
#   'data': [[0.11538461538461536],
#    [0.10946599501848521],
#    [0.09716221956140307],
#    [0.08460728057073365],
#    [0.07331968054347758],
#    [0.06361438633761876],
#    [0.0555099490401283],
#    [0.04874703420697742],
#    [0.04311333533914652],
#    [0.03842528066531529],
#    [0.034477172105658434],
#    [0.03113264132992362],
#    [0.028274833426694006],
#    [0.025813971121216604],
#    [0.02369268385423546],
#    [0.021843287496748673],
#    [0.02022399836761945],
#    [0.018799021335218387],
#    [0.01753043061111359],
#    [0.01639455813816829]]},
#  {'_id': '-130_32_-132.0_32.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-132, 32]},
#   'data': [[0.15384615384615383],
#    [0.1284121541301736],
#    [0.09985909783311472],
#    [0.07750544647589604],
#    [0.06092583340566979],
#    [0.04879210685140892],
#    [0.03995587210840804],
#    [0.03344046536888199],
#    [0.0285793105859301],
#    [0.02490483991343622],
#    [0.022062266203851513],
#    [0.019823049518404467],
#    [0.01802439781451297],
#    [0.016551497002779792],
#    [0.015332357614147552],
#    [0.014302520744460652],
#    [0.013421966809987767],
#    [0.012660443658708762],
#    [0.011989607273563675],
#    [0.011391778814772418]]},
#  {'_id': '-130_32_-130.0_34.0',
#   'metadata': ['argone'],
#   'geolocation': {'type': 'Point', 'coordinates': [-130, 32]},
#   'geolocation_forecast': {'type': 'Point', 'coordinates': [-130, 34]},
#   'data': [[0.13461538461538458],
#    [0.13753076215686932],
#    [0.12010402096125147],
#    [0.10149604522095113],
#    [0.085516904432761],
#    [0.07252470483399512],
#    [0.06219759942181557],
#    [0.053946098237650425],
#    [0.04732517859457752],
#    [0.04198755426534437],
#    [0.037613679436565996],
#    [0.033991778473164744],
#    [0.030954053175372632],
#    [0.02837480308999405],
#    [0.02617468407969929],
#    [0.024269888683794507],
#    [0.02260870244480325],
#    [0.02114895735992667],
#    [0.019848015146965197],
#    [0.018679595022339037]]}]

# %%
deltat_forecast = 270
gridmap = ds.loc[{"forecastDays":deltat_forecast}]
fig = gridmap['probability'].plot()

# %% [markdown]
# Or, we could turn it into numpy arrays and plot on a map (please note the x0, y0 origin we selected is indicated as a black star):

# %%
dlon = 2
dlat = 2

fnt_sz = 26

lon_edges = np.arange(-180,180+dlon,dlon)
lat_edges = np.arange(-90,90+dlat,dlat)

c = np.zeros((len(lat_edges),len(lon_edges)))
c[:] = None

def coord2bin(longitude, latitude):
    lonbin = np.argmax(lon_edges>longitude)
    latbin = np.argmax(lat_edges>latitude)
    return (latbin-1, lonbin-1)

for doc in flf:
    dest_long = doc['geolocation_forecast']['coordinates'][0]
    dest_lat = doc['geolocation_forecast']['coordinates'][1]
    coords = coord2bin(dest_long, dest_lat)
    c[coords[0], coords[1]] = doc['data'][flfMeta[0]['data_info'][0].index(str(deltat_forecast))][0]

fig = plt.figure(figsize=(42, 14))
ax = plt.axes(projection=ccrs.PlateCarree())
plt.pcolormesh(lon_edges+dlon/2, lat_edges+dlat/2, c, transform=ccrs.PlateCarree(),cmap='Reds',
              alpha=.6)
cbar = plt.colorbar()
cbar.set_label('probability', rotation=270,fontsize=fnt_sz, labelpad=30)
cbar.ax.tick_params(labelsize=fnt_sz)

plt.plot(x0,y0,'*',markersize=15*3, color='k', transform=ccrs.PlateCarree())
plt.plot(x0,y0,'*',markersize=3*3, color='w', transform=ccrs.PlateCarree())

plt.title(str(deltat_forecast) + ' day forecast for float beginning at ' + str(x0) + ',' + str(y0) + ' (star)',
          fontsize=fnt_sz)
ax.stock_img()
ax.coastlines()
ax.set_extent([x0-20, x0+60, y0-15, y0+20], crs=ccrs.PlateCarree())
plt.show()
